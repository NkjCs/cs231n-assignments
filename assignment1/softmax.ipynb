# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.406920
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *When W is nearly a zero matrix loss = -log(1/number of classes). here number of classes=10 hence loss = -log(0.1)*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.117667 analytic: -0.117667, relative error: 5.716946e-08
# numerical: -4.568322 analytic: -4.568322, relative error: 3.012154e-09
# numerical: 0.354545 analytic: 0.354545, relative error: 1.933506e-07
# numerical: 2.156839 analytic: 2.156838, relative error: 2.954243e-08
# numerical: -2.540737 analytic: -2.540737, relative error: 3.936533e-09
# numerical: 2.227393 analytic: 2.227393, relative error: 1.193150e-09
# numerical: 4.275240 analytic: 4.275240, relative error: 1.293129e-08
# numerical: -0.222463 analytic: -0.222463, relative error: 2.526629e-07
# numerical: 1.113186 analytic: 1.113186, relative error: 3.604130e-08
# numerical: 0.501275 analytic: 0.501275, relative error: 3.179016e-08
# numerical: 1.284740 analytic: 1.284740, relative error: 8.752828e-09
# numerical: 1.263961 analytic: 1.263960, relative error: 7.666869e-08
# numerical: 0.788119 analytic: 0.788119, relative error: 5.998613e-08
# numerical: -1.093041 analytic: -1.093041, relative error: 6.302273e-08
# numerical: -0.315811 analytic: -0.315811, relative error: 1.581162e-07
# numerical: -0.766547 analytic: -0.766547, relative error: 1.361873e-08
# numerical: -1.735672 analytic: -1.735672, relative error: 9.735884e-10
# numerical: -1.431379 analytic: -1.431379, relative error: 4.066499e-08
# numerical: -0.956415 analytic: -0.956415, relative error: 3.500509e-08
# numerical: 1.149935 analytic: 1.149935, relative error: 3.920420e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.406920e+00 computed in 0.122701s
# vectorized loss: 2.406920e+00 computed in 0.000000s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = np.linspace(8e-8, 2e-7,10)
regularization_strengths = np.linspace(1e4, 5e4,3)

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in learning_rates:
  for reg in regularization_strengths:
    clf=Softmax()
    loss_hist = clf.train(X_train, y_train, learning_rate=lr, reg=reg,
                      num_iters=1500, verbose=True)
    y_train_pred = clf.predict(X_train)
    y_val_pred = clf.predict(X_val)
    train_acc=np.mean(y_train == y_train_pred)
    val_acc=np.mean(y_val == y_val_pred)
    results[(lr,reg)]=train_acc,val_acc
    if(val_acc>best_val):
        best_softmax=clf
        best_val=val_acc
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 313.349355
# iteration 100 / 1500: loss 226.377261
# iteration 200 / 1500: loss 164.321483
# iteration 300 / 1500: loss 119.627697
# iteration 400 / 1500: loss 87.214669
# iteration 500 / 1500: loss 63.774021
# iteration 600 / 1500: loss 46.748440
# iteration 700 / 1500: loss 34.491658
# iteration 800 / 1500: loss 25.473095
# iteration 900 / 1500: loss 19.007470
# iteration 1000 / 1500: loss 14.311483
# iteration 1100 / 1500: loss 10.973828
# iteration 1200 / 1500: loss 8.541397
# iteration 1300 / 1500: loss 6.685985
# iteration 1400 / 1500: loss 5.358392
# iteration 0 / 1500: loss 909.835305
# iteration 100 / 1500: loss 347.599282
# iteration 200 / 1500: loss 133.805753
# iteration 300 / 1500: loss 52.324932
# iteration 400 / 1500: loss 21.220125
# iteration 500 / 1500: loss 9.454804
# iteration 600 / 1500: loss 4.858137
# iteration 700 / 1500: loss 3.206569
# iteration 800 / 1500: loss 2.517105
# iteration 900 / 1500: loss 2.347293
# iteration 1000 / 1500: loss 2.115933
# iteration 1100 / 1500: loss 2.112940
# iteration 1200 / 1500: loss 2.102278
# iteration 1300 / 1500: loss 2.088621
# iteration 1400 / 1500: loss 2.142177
# iteration 0 / 1500: loss 1542.400062
# iteration 100 / 1500: loss 310.137790
# iteration 200 / 1500: loss 63.738097
# iteration 300 / 1500: loss 14.434835
# iteration 400 / 1500: loss 4.602553
# iteration 500 / 1500: loss 2.662614
# iteration 600 / 1500: loss 2.212245
# iteration 700 / 1500: loss 2.180038
# iteration 800 / 1500: loss 2.149174
# iteration 900 / 1500: loss 2.154475
# iteration 1000 / 1500: loss 2.162036
# iteration 1100 / 1500: loss 2.122059
# iteration 1200 / 1500: loss 2.157666
# iteration 1300 / 1500: loss 2.117981
# iteration 1400 / 1500: loss 2.140274
# iteration 0 / 1500: loss 312.250373
# iteration 100 / 1500: loss 213.841912
# iteration 200 / 1500: loss 147.263923
# iteration 300 / 1500: loss 101.718030
# iteration 400 / 1500: loss 70.379564
# iteration 500 / 1500: loss 49.086821
# iteration 600 / 1500: loss 34.312681
# iteration 700 / 1500: loss 24.220237
# iteration 800 / 1500: loss 17.272755
# iteration 900 / 1500: loss 12.504639
# iteration 1000 / 1500: loss 9.265512
# iteration 1100 / 1500: loss 6.949010
# iteration 1200 / 1500: loss 5.449472
# iteration 1300 / 1500: loss 4.320830
# iteration 1400 / 1500: loss 3.618711
# iteration 0 / 1500: loss 919.663371
# iteration 100 / 1500: loss 299.361107
# iteration 200 / 1500: loss 98.532905
# iteration 300 / 1500: loss 33.415503
# iteration 400 / 1500: loss 12.345900
# iteration 500 / 1500: loss 5.362568
# iteration 600 / 1500: loss 3.165937
# iteration 700 / 1500: loss 2.450383
# iteration 800 / 1500: loss 2.172490
# iteration 900 / 1500: loss 2.174174
# iteration 1000 / 1500: loss 2.157775
# iteration 1100 / 1500: loss 2.136745
# iteration 1200 / 1500: loss 2.117251
# iteration 1300 / 1500: loss 2.061928
# iteration 1400 / 1500: loss 2.086809
# iteration 0 / 1500: loss 1536.419668
# iteration 100 / 1500: loss 236.646008
# iteration 200 / 1500: loss 38.022484
# iteration 300 / 1500: loss 7.603204
# iteration 400 / 1500: loss 2.988673
# iteration 500 / 1500: loss 2.264742
# iteration 600 / 1500: loss 2.156732
# iteration 700 / 1500: loss 2.134542
# iteration 800 / 1500: loss 2.086105
# iteration 900 / 1500: loss 2.150303
# iteration 1000 / 1500: loss 2.172110
# iteration 1100 / 1500: loss 2.147226
# iteration 1200 / 1500: loss 2.161644
# iteration 1300 / 1500: loss 2.144817
# iteration 1400 / 1500: loss 2.145295
# iteration 0 / 1500: loss 307.261696
# iteration 100 / 1500: loss 200.290635
# iteration 200 / 1500: loss 130.858078
# iteration 300 / 1500: loss 85.875578
# iteration 400 / 1500: loss 56.460832
# iteration 500 / 1500: loss 37.438476
# iteration 600 / 1500: loss 25.046006
# iteration 700 / 1500: loss 17.062588
# iteration 800 / 1500: loss 11.808583
# iteration 900 / 1500: loss 8.327023
# iteration 1000 / 1500: loss 6.159873
# iteration 1100 / 1500: loss 4.644395
# iteration 1200 / 1500: loss 3.727381
# iteration 1300 / 1500: loss 3.117361
# iteration 1400 / 1500: loss 2.779490
# iteration 0 / 1500: loss 924.898023
# iteration 100 / 1500: loss 256.579244
# iteration 200 / 1500: loss 72.391846
# iteration 300 / 1500: loss 21.532612
# iteration 400 / 1500: loss 7.493654
# iteration 500 / 1500: loss 3.583488
# iteration 600 / 1500: loss 2.474093
# iteration 700 / 1500: loss 2.206110
# iteration 800 / 1500: loss 2.088992
# iteration 900 / 1500: loss 2.087188
# iteration 1000 / 1500: loss 2.124833
# iteration 1100 / 1500: loss 2.145957
# iteration 1200 / 1500: loss 2.125961
# iteration 1300 / 1500: loss 2.146818
# iteration 1400 / 1500: loss 2.042207
# iteration 0 / 1500: loss 1540.211946
# iteration 100 / 1500: loss 181.387672
# iteration 200 / 1500: loss 23.089500
# iteration 300 / 1500: loss 4.584005
# iteration 400 / 1500: loss 2.419381
# iteration 500 / 1500: loss 2.154188
# iteration 600 / 1500: loss 2.161342
# iteration 700 / 1500: loss 2.127483
# iteration 800 / 1500: loss 2.115982
# iteration 900 / 1500: loss 2.155745
# iteration 1000 / 1500: loss 2.160485
# iteration 1100 / 1500: loss 2.083453
# iteration 1200 / 1500: loss 2.176820
# iteration 1300 / 1500: loss 2.192303
# iteration 1400 / 1500: loss 2.165456
# iteration 0 / 1500: loss 312.083225
# iteration 100 / 1500: loss 192.338283
# iteration 200 / 1500: loss 119.269331
# iteration 300 / 1500: loss 74.220824
# iteration 400 / 1500: loss 46.428389
# iteration 500 / 1500: loss 29.500176
# iteration 600 / 1500: loss 18.976353
# iteration 700 / 1500: loss 12.452472
# iteration 800 / 1500: loss 8.514655
# iteration 900 / 1500: loss 6.016625
# iteration 1000 / 1500: loss 4.518546
# iteration 1100 / 1500: loss 3.535676
# iteration 1200 / 1500: loss 2.957011
# iteration 1300 / 1500: loss 2.664142
# iteration 1400 / 1500: loss 2.325585
# iteration 0 / 1500: loss 928.644250
# iteration 100 / 1500: loss 219.379650
# iteration 200 / 1500: loss 53.109501
# iteration 300 / 1500: loss 14.093318
# iteration 400 / 1500: loss 4.857874
# iteration 500 / 1500: loss 2.808443
# iteration 600 / 1500: loss 2.267100
# iteration 700 / 1500: loss 2.102810
# iteration 800 / 1500: loss 2.187548
# iteration 900 / 1500: loss 2.085585
# iteration 1000 / 1500: loss 2.084942
# iteration 1100 / 1500: loss 2.113566
# iteration 1200 / 1500: loss 2.036065
# iteration 1300 / 1500: loss 2.121435
# iteration 1400 / 1500: loss 2.064851
# iteration 0 / 1500: loss 1520.571378
# iteration 100 / 1500: loss 137.341383
# iteration 200 / 1500: loss 14.209237
# iteration 300 / 1500: loss 3.211267
# iteration 400 / 1500: loss 2.243558
# iteration 500 / 1500: loss 2.131421
# iteration 600 / 1500: loss 2.131150
# iteration 700 / 1500: loss 2.143872
# iteration 800 / 1500: loss 2.168064
# iteration 900 / 1500: loss 2.119700
# iteration 1000 / 1500: loss 2.164809
# iteration 1100 / 1500: loss 2.108660
# iteration 1200 / 1500: loss 2.105015
# iteration 1300 / 1500: loss 2.144471
# iteration 1400 / 1500: loss 2.164835
# iteration 0 / 1500: loss 310.613305
# iteration 100 / 1500: loss 181.551186
# iteration 200 / 1500: loss 106.881145
# iteration 300 / 1500: loss 63.363678
# iteration 400 / 1500: loss 37.871155
# iteration 500 / 1500: loss 23.007638
# iteration 600 / 1500: loss 14.187455
# iteration 700 / 1500: loss 9.172758
# iteration 800 / 1500: loss 6.206733
# iteration 900 / 1500: loss 4.481404
# iteration 1000 / 1500: loss 3.519180
# iteration 1100 / 1500: loss 2.836411
# iteration 1200 / 1500: loss 2.515764
# iteration 1300 / 1500: loss 2.372500
# iteration 1400 / 1500: loss 2.145368
# iteration 0 / 1500: loss 924.620606
# iteration 100 / 1500: loss 186.263113
# iteration 200 / 1500: loss 38.965582
# iteration 300 / 1500: loss 9.444909
# iteration 400 / 1500: loss 3.563938
# iteration 500 / 1500: loss 2.429558
# iteration 600 / 1500: loss 2.100518
# iteration 700 / 1500: loss 2.105729
# iteration 800 / 1500: loss 2.107146
# iteration 900 / 1500: loss 2.142455
# iteration 1000 / 1500: loss 2.061921
# iteration 1100 / 1500: loss 2.101316
# iteration 1200 / 1500: loss 2.099456
# iteration 1300 / 1500: loss 2.092164
# iteration 1400 / 1500: loss 2.100316
# iteration 0 / 1500: loss 1547.145782
# iteration 100 / 1500: loss 107.017934
# iteration 200 / 1500: loss 9.281302
# iteration 300 / 1500: loss 2.655685
# iteration 400 / 1500: loss 2.160232
# iteration 500 / 1500: loss 2.184857
# iteration 600 / 1500: loss 2.142506
# iteration 700 / 1500: loss 2.141244
# iteration 800 / 1500: loss 2.175113
# iteration 900 / 1500: loss 2.144275
# iteration 1000 / 1500: loss 2.113570
# iteration 1100 / 1500: loss 2.142445
# iteration 1200 / 1500: loss 2.115299
# iteration 1300 / 1500: loss 2.166714
# iteration 1400 / 1500: loss 2.160382
# iteration 0 / 1500: loss 317.686637
# iteration 100 / 1500: loss 175.759880
# iteration 200 / 1500: loss 98.292070
# iteration 300 / 1500: loss 55.304599
# iteration 400 / 1500: loss 31.484582
# iteration 500 / 1500: loss 18.405179
# iteration 600 / 1500: loss 11.066172
# iteration 700 / 1500: loss 6.990781
# iteration 800 / 1500: loss 4.808324
# iteration 900 / 1500: loss 3.580385
# iteration 1000 / 1500: loss 2.894215
# iteration 1100 / 1500: loss 2.485450
# iteration 1200 / 1500: loss 2.325898
# iteration 1300 / 1500: loss 2.170124
# iteration 1400 / 1500: loss 2.098978
# iteration 0 / 1500: loss 919.024638
# iteration 100 / 1500: loss 157.901559
# iteration 200 / 1500: loss 28.567631
# iteration 300 / 1500: loss 6.612492
# iteration 400 / 1500: loss 2.851616
# iteration 500 / 1500: loss 2.254869
# iteration 600 / 1500: loss 2.131385
# iteration 700 / 1500: loss 2.048938
# iteration 800 / 1500: loss 2.082327
# iteration 900 / 1500: loss 2.069062
# iteration 1000 / 1500: loss 2.116150
# iteration 1100 / 1500: loss 2.086953
# iteration 1200 / 1500: loss 2.128396
# iteration 1300 / 1500: loss 2.097558
# iteration 1400 / 1500: loss 2.096594
# iteration 0 / 1500: loss 1542.021927
# iteration 100 / 1500: loss 81.809502
# iteration 200 / 1500: loss 6.280701
# iteration 300 / 1500: loss 2.336970
# iteration 400 / 1500: loss 2.129240
# iteration 500 / 1500: loss 2.128447
# iteration 600 / 1500: loss 2.160803
# iteration 700 / 1500: loss 2.162347
# iteration 800 / 1500: loss 2.142221
# iteration 900 / 1500: loss 2.187386
# iteration 1000 / 1500: loss 2.144110
# iteration 1100 / 1500: loss 2.173572
# iteration 1200 / 1500: loss 2.134483
# iteration 1300 / 1500: loss 2.164913
# iteration 1400 / 1500: loss 2.153353
# iteration 0 / 1500: loss 314.171570
# iteration 100 / 1500: loss 164.901320
# iteration 200 / 1500: loss 87.423954
# iteration 300 / 1500: loss 46.937632
# iteration 400 / 1500: loss 25.678778
# iteration 500 / 1500: loss 14.318001
# iteration 600 / 1500: loss 8.508249
# iteration 700 / 1500: loss 5.327585
# iteration 800 / 1500: loss 3.793143
# iteration 900 / 1500: loss 2.930864
# iteration 1000 / 1500: loss 2.437159
# iteration 1100 / 1500: loss 2.234496
# iteration 1200 / 1500: loss 2.166917
# iteration 1300 / 1500: loss 2.001103
# iteration 1400 / 1500: loss 2.050562
# iteration 0 / 1500: loss 932.396286
# iteration 100 / 1500: loss 136.594848
# iteration 200 / 1500: loss 21.550731
# iteration 300 / 1500: loss 4.974376
# iteration 400 / 1500: loss 2.537267
# iteration 500 / 1500: loss 2.177247
# iteration 600 / 1500: loss 2.052946
# iteration 700 / 1500: loss 2.139376
# iteration 800 / 1500: loss 2.018362
# iteration 900 / 1500: loss 2.115288
# iteration 1000 / 1500: loss 2.079077
# iteration 1100 / 1500: loss 2.141612
# iteration 1200 / 1500: loss 2.071043
# iteration 1300 / 1500: loss 2.106254
# iteration 1400 / 1500: loss 2.058568
# iteration 0 / 1500: loss 1541.299576
# iteration 100 / 1500: loss 62.861734
# iteration 200 / 1500: loss 4.540332
# iteration 300 / 1500: loss 2.198940
# iteration 400 / 1500: loss 2.141030
# iteration 500 / 1500: loss 2.124746
# iteration 600 / 1500: loss 2.088835
# iteration 700 / 1500: loss 2.143112
# iteration 800 / 1500: loss 2.155848
# iteration 900 / 1500: loss 2.124502
# iteration 1000 / 1500: loss 2.185840
# iteration 1100 / 1500: loss 2.115921
# iteration 1200 / 1500: loss 2.117609
# iteration 1300 / 1500: loss 2.146458
# iteration 1400 / 1500: loss 2.125040
# iteration 0 / 1500: loss 313.788712
# iteration 100 / 1500: loss 156.515721
# iteration 200 / 1500: loss 78.732298
# iteration 300 / 1500: loss 40.144811
# iteration 400 / 1500: loss 21.104419
# iteration 500 / 1500: loss 11.477482
# iteration 600 / 1500: loss 6.770638
# iteration 700 / 1500: loss 4.352413
# iteration 800 / 1500: loss 3.162168
# iteration 900 / 1500: loss 2.616082
# iteration 1000 / 1500: loss 2.392441
# iteration 1100 / 1500: loss 2.166458
# iteration 1200 / 1500: loss 2.073291
# iteration 1300 / 1500: loss 2.073866
# iteration 1400 / 1500: loss 2.058160
# iteration 0 / 1500: loss 935.996473
# iteration 100 / 1500: loss 116.764109
# iteration 200 / 1500: loss 16.180771
# iteration 300 / 1500: loss 3.832796
# iteration 400 / 1500: loss 2.303223
# iteration 500 / 1500: loss 2.161659
# iteration 600 / 1500: loss 2.110938
# iteration 700 / 1500: loss 2.083853
# iteration 800 / 1500: loss 2.116707
# iteration 900 / 1500: loss 2.079020
# iteration 1000 / 1500: loss 2.168927
# iteration 1100 / 1500: loss 2.038793
# iteration 1200 / 1500: loss 2.101162
# iteration 1300 / 1500: loss 2.129288
# iteration 1400 / 1500: loss 2.089073
# iteration 0 / 1500: loss 1536.897415
# iteration 100 / 1500: loss 48.394687
# iteration 200 / 1500: loss 3.542074
# iteration 300 / 1500: loss 2.142545
# iteration 400 / 1500: loss 2.203218
# iteration 500 / 1500: loss 2.166125
# iteration 600 / 1500: loss 2.126749
# iteration 700 / 1500: loss 2.149177
# iteration 800 / 1500: loss 2.114589
# iteration 900 / 1500: loss 2.179681
# iteration 1000 / 1500: loss 2.144480
# iteration 1100 / 1500: loss 2.150888
# iteration 1200 / 1500: loss 2.181276
# iteration 1300 / 1500: loss 2.152042
# iteration 1400 / 1500: loss 2.131305
# iteration 0 / 1500: loss 313.144535
# iteration 100 / 1500: loss 148.135460
# iteration 200 / 1500: loss 70.713572
# iteration 300 / 1500: loss 34.421979
# iteration 400 / 1500: loss 17.212823
# iteration 500 / 1500: loss 9.175466
# iteration 600 / 1500: loss 5.418020
# iteration 700 / 1500: loss 3.644769
# iteration 800 / 1500: loss 2.755794
# iteration 900 / 1500: loss 2.404254
# iteration 1000 / 1500: loss 2.205607
# iteration 1100 / 1500: loss 1.983410
# iteration 1200 / 1500: loss 2.093709
# iteration 1300 / 1500: loss 2.008658
# iteration 1400 / 1500: loss 1.990174
# iteration 0 / 1500: loss 927.881670
# iteration 100 / 1500: loss 98.702824
# iteration 200 / 1500: loss 12.261934
# iteration 300 / 1500: loss 3.143759
# iteration 400 / 1500: loss 2.114456
# iteration 500 / 1500: loss 2.097757
# iteration 600 / 1500: loss 2.139136
# iteration 700 / 1500: loss 2.134585
# iteration 800 / 1500: loss 2.089087
# iteration 900 / 1500: loss 2.119320
# iteration 1000 / 1500: loss 2.150092
# iteration 1100 / 1500: loss 2.153841
# iteration 1200 / 1500: loss 2.146224
# iteration 1300 / 1500: loss 2.132886
# iteration 1400 / 1500: loss 2.150696
# iteration 0 / 1500: loss 1530.001211
# iteration 100 / 1500: loss 37.157555
# iteration 200 / 1500: loss 2.979667
# iteration 300 / 1500: loss 2.151618
# iteration 400 / 1500: loss 2.161116
# iteration 500 / 1500: loss 2.123542
# iteration 600 / 1500: loss 2.156584
# iteration 700 / 1500: loss 2.174837
# iteration 800 / 1500: loss 2.198043
# iteration 900 / 1500: loss 2.110110
# iteration 1000 / 1500: loss 2.109261
# iteration 1100 / 1500: loss 2.178568
# iteration 1200 / 1500: loss 2.066448
# iteration 1300 / 1500: loss 2.155439
# iteration 1400 / 1500: loss 2.122186
# iteration 0 / 1500: loss 313.227596
# iteration 100 / 1500: loss 139.972837
# iteration 200 / 1500: loss 63.617187
# iteration 300 / 1500: loss 29.629809
# iteration 400 / 1500: loss 14.356217
# iteration 500 / 1500: loss 7.494750
# iteration 600 / 1500: loss 4.467137
# iteration 700 / 1500: loss 3.036168
# iteration 800 / 1500: loss 2.517402
# iteration 900 / 1500: loss 2.238663
# iteration 1000 / 1500: loss 2.111065
# iteration 1100 / 1500: loss 2.019589
# iteration 1200 / 1500: loss 2.000019
# iteration 1300 / 1500: loss 2.045535
# iteration 1400 / 1500: loss 2.037605
# iteration 0 / 1500: loss 932.321184
# iteration 100 / 1500: loss 84.713240
# iteration 200 / 1500: loss 9.398967
# iteration 300 / 1500: loss 2.732954
# iteration 400 / 1500: loss 2.157221
# iteration 500 / 1500: loss 2.087385
# iteration 600 / 1500: loss 2.090606
# iteration 700 / 1500: loss 2.154585
# iteration 800 / 1500: loss 2.037756
# iteration 900 / 1500: loss 2.059820
# iteration 1000 / 1500: loss 2.074032
# iteration 1100 / 1500: loss 2.125145
# iteration 1200 / 1500: loss 2.104671
# iteration 1300 / 1500: loss 2.070790
# iteration 1400 / 1500: loss 2.091778
# iteration 0 / 1500: loss 1548.234720
# iteration 100 / 1500: loss 29.082655
# iteration 200 / 1500: loss 2.605486
# iteration 300 / 1500: loss 2.114652
# iteration 400 / 1500: loss 2.135400
# iteration 500 / 1500: loss 2.112670
# iteration 600 / 1500: loss 2.178757
# iteration 700 / 1500: loss 2.168916
# iteration 800 / 1500: loss 2.128312
# iteration 900 / 1500: loss 2.145376
# iteration 1000 / 1500: loss 2.195261
# iteration 1100 / 1500: loss 2.223580
# iteration 1200 / 1500: loss 2.171378
# iteration 1300 / 1500: loss 2.116611
# iteration 1400 / 1500: loss 2.133616
# lr 8.000000e-08 reg 1.000000e+04 train accuracy: 0.344163 val accuracy: 0.363000
# lr 8.000000e-08 reg 3.000000e+04 train accuracy: 0.327184 val accuracy: 0.341000
# lr 8.000000e-08 reg 5.000000e+04 train accuracy: 0.302020 val accuracy: 0.314000
# lr 9.333333e-08 reg 1.000000e+04 train accuracy: 0.351633 val accuracy: 0.369000
# lr 9.333333e-08 reg 3.000000e+04 train accuracy: 0.324122 val accuracy: 0.338000
# lr 9.333333e-08 reg 5.000000e+04 train accuracy: 0.306531 val accuracy: 0.320000
# lr 1.066667e-07 reg 1.000000e+04 train accuracy: 0.355388 val accuracy: 0.371000
# lr 1.066667e-07 reg 3.000000e+04 train accuracy: 0.319469 val accuracy: 0.331000
# lr 1.066667e-07 reg 5.000000e+04 train accuracy: 0.297755 val accuracy: 0.316000
# lr 1.200000e-07 reg 1.000000e+04 train accuracy: 0.352388 val accuracy: 0.370000
# lr 1.200000e-07 reg 3.000000e+04 train accuracy: 0.324184 val accuracy: 0.346000
# lr 1.200000e-07 reg 5.000000e+04 train accuracy: 0.314592 val accuracy: 0.333000
# lr 1.333333e-07 reg 1.000000e+04 train accuracy: 0.357041 val accuracy: 0.363000
# lr 1.333333e-07 reg 3.000000e+04 train accuracy: 0.318388 val accuracy: 0.328000
# lr 1.333333e-07 reg 5.000000e+04 train accuracy: 0.302816 val accuracy: 0.317000
# lr 1.466667e-07 reg 1.000000e+04 train accuracy: 0.355000 val accuracy: 0.369000
# lr 1.466667e-07 reg 3.000000e+04 train accuracy: 0.319102 val accuracy: 0.326000
# lr 1.466667e-07 reg 5.000000e+04 train accuracy: 0.308837 val accuracy: 0.334000
# lr 1.600000e-07 reg 1.000000e+04 train accuracy: 0.360204 val accuracy: 0.376000
# lr 1.600000e-07 reg 3.000000e+04 train accuracy: 0.322286 val accuracy: 0.333000
# lr 1.600000e-07 reg 5.000000e+04 train accuracy: 0.302163 val accuracy: 0.324000
# lr 1.733333e-07 reg 1.000000e+04 train accuracy: 0.358449 val accuracy: 0.362000
# lr 1.733333e-07 reg 3.000000e+04 train accuracy: 0.323224 val accuracy: 0.340000
# lr 1.733333e-07 reg 5.000000e+04 train accuracy: 0.315633 val accuracy: 0.335000
# lr 1.866667e-07 reg 1.000000e+04 train accuracy: 0.352449 val accuracy: 0.373000
# lr 1.866667e-07 reg 3.000000e+04 train accuracy: 0.321204 val accuracy: 0.341000
# lr 1.866667e-07 reg 5.000000e+04 train accuracy: 0.314714 val accuracy: 0.323000
# lr 2.000000e-07 reg 1.000000e+04 train accuracy: 0.357755 val accuracy: 0.369000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.325184 val accuracy: 0.344000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.311755 val accuracy: 0.320000
# best validation accuracy achieved during cross-validation: 0.376000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.365000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$True
#
#
# $\color{blue}{\textit Your Explanation:}$ In svm loss depends on the relative score and if the score of the added datapoint is 1(margin) less than the correct score then the total loss remains unchanged whereas in softmax every datapoint has some contribution in the total loss.

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
